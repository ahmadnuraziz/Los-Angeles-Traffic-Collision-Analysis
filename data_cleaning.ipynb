# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('traffic-collision-data-from-2010-to-present.csv')
data.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  191713007  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1040
# 1  191913696  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            850
# 2  191611704  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            910
# 3  191913694  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            700
# 4  191514323  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1200
#
#    Area ID    Area Name  Reporting District  Crime Code  \
# 0       17   Devonshire                1788         997
# 1       19      Mission                1924         997
# 2       16     Foothill                1693         997
# 3       19      Mission                1964         997
# 4       15  N Hollywood                1513         997
#
#   Crime Code Description MO Codes  ...  Premise Description  \
# 0      TRAFFIC COLLISION      NaN  ...               STREET
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481568 entries, 0 to 481567
# Data columns (total 24 columns):
# DR Number                            481568 non-null int64
# Date Reported                        481568 non-null object
# Date Occurred                        481568 non-null object
# Time Occurred                        481568 non-null int64
# Area ID                              481568 non-null int64
# Area Name                            481568 non-null object
# Reporting District                   481568 non-null int64
# Crime Code                           481568 non-null int64
# Crime Code Description               481568 non-null object
# MO Codes                             396722 non-null object
# Victim Age                           404022 non-null float64
# Victim Sex                           474522 non-null object
# Victim Descent                       473786 non-null object
# Premise Code                         481543 non-null float64
# ...

# %%
data.drop(['LA Specific Plans','MO Codes'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  191713007  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1040
# 1  191913696  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            850
# 2  191611704  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            910
# 3  191913694  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            700
# 4  191514323  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1200
#
#    Area ID    Area Name  Reporting District  Crime Code  \
# 0       17   Devonshire                1788         997
# 1       19      Mission                1924         997
# 2       16     Foothill                1693         997
# 3       19      Mission                1964         997
# 4       15  N Hollywood                1513         997
#
#   Crime Code Description  Victim Age  ... Premise Code Premise Description  \
# 0      TRAFFIC COLLISION        32.0  ...        101.0              STREET
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481568 entries, 0 to 481567
# Data columns (total 22 columns):
# DR Number                            481568 non-null int64
# Date Reported                        481568 non-null object
# Date Occurred                        481568 non-null object
# Time Occurred                        481568 non-null int64
# Area ID                              481568 non-null int64
# Area Name                            481568 non-null object
# Reporting District                   481568 non-null int64
# Crime Code                           481568 non-null int64
# Crime Code Description               481568 non-null object
# Victim Age                           404022 non-null float64
# Victim Sex                           474522 non-null object
# Victim Descent                       473786 non-null object
# Premise Code                         481543 non-null float64
# Premise Description                  481543 non-null object
# ...

# %%
data.describe()
# Out:
#           DR Number  Time Occurred        Area ID  Reporting District  \
# count  4.815680e+05  481568.000000  481568.000000       481568.000000
# mean   1.466924e+08    1354.935463      11.068956         1153.043846
# std    2.762947e+07     596.928844       5.876958          588.979929
# min    1.001000e+08       1.000000       1.000000          100.000000
# 25%    1.214262e+08     930.000000       6.000000          666.000000
# 50%    1.506238e+08    1430.000000      11.000000         1149.000000
# 75%    1.710118e+08    1820.000000      16.000000         1651.000000
# max    1.921131e+08    2359.000000      21.000000         2199.000000
#
#        Crime Code     Victim Age   Premise Code      Zip Codes  Census Tracts  \
# count    481568.0  404022.000000  481543.000000  481170.000000  475034.000000
# mean        997.0      41.547139     102.430967   20174.714513     561.056013
# std           0.0      16.197300      23.295022    6025.297527     390.495524
# ...

# %%
data.drop('Crime Code',axis=1,inplace=True)

# %%
data['Area Name'].unique()
# Out:
# array(['Devonshire', 'Mission', 'Foothill', 'N Hollywood', 'Wilshire',
#        'West LA', 'Rampart', 'Van Nuys', 'Northeast', 'West Valley',
#        'Newton', 'Southwest', 'Southeast', 'Topanga', 'Hollenbeck',
#        'Central', 'Pacific', '77th Street', 'Harbor', 'Olympic',
#        'Hollywood'], dtype=object)

# %%
data['Premise Code'].unique()
# Out:
# array([ 101.,  108.,  102.,  301.,  710.,  104.,  151.,  103.,  116.,
#         704.,  701.,  601.,  110.,  123.,  415.,  212.,  732.,  120.,
#         253.,  107.,  726.,  247.,  725.,  122.,  106.,  702.,  503.,
#         203.,  501.,  707.,  502.,  156.,  202.,  109.,  504.,  232.,
#         142.,  215.,  714.,  402.,  121.,  602.,  417.,  210.,  124.,
#         111.,  510.,  213.,  222.,  752.,  901.,  733.,  720.,  118.,
#         221.,  727.,  144.,  719.,  154.,  703.,  105.,  119.,  937.,
#         708.,   nan,  243.,  126.,  135.,  141.,  406.,  509.,  410.,
#         511.,  117.,  721.,  735.,  207.,  718.,  129.,  811.,  505.,
#         411.,  809.,  211.,  401.,  404.,  131.,  705.,  239.,  723.,
#         408.,  228.,  113.,  722.,  251.,  706.,  208.,  115.,  405.,
#         206.,  407.,  145.,  801.,  137.,  204.,  403.,  605.,  220.,
#         138.,  112.,  214.,  738.])

# %%
data['Crime Code Description'].unique()
# Out:
# array(['TRAFFIC COLLISION'], dtype=object)

# %%
data.drop('Crime Code Description',axis=1,inplace=True)

# %%
data.drop('Premise Code',axis=1,inplace=True)

# %%
data.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  191713007  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1040
# 1  191913696  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            850
# 2  191611704  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            910
# 3  191913694  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            700
# 4  191514323  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1200
#
#    Area ID    Area Name  Reporting District  Victim Age Victim Sex  \
# 0       17   Devonshire                1788        32.0          F
# 1       19      Mission                1924        50.0          M
# 2       16     Foothill                1693        75.0          M
# 3       19      Mission                1964        40.0          M
# 4       15  N Hollywood                1513        27.0          M
#
#   Victim Descent Premise Description                          Address  \
# ...

# %%
data.drop('Area ID',axis=1,inplace=True)

# %%
import re
latitude = np.zeros(len(data))
longitude = np.zeros(len(data))
for i in range(len(data)):
    latitude[i] = float(data.loc[i,'Location'].split(':')[1].split(',')[0].replace(' ','').replace("'",''))
    longitude[i] = float(data.loc[i,'Location'].split(':')[-1].replace("'",'').replace(' ','').replace('}',''))

# %%
data['Latitude'] = pd.DataFrame({'Latitude':latitude})
data['Longitude'] = pd.DataFrame({'Longitude':longitude})

# %%
data.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  191713007  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1040
# 1  191913696  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            850
# 2  191611704  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            910
# 3  191913694  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            700
# 4  191514323  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1200
#
#      Area Name  Reporting District  Victim Age Victim Sex Victim Descent  \
# 0   Devonshire                1788        32.0          F              W
# 1      Mission                1924        50.0          M              O
# 2     Foothill                1693        75.0          M              O
# 3      Mission                1964        40.0          M              H
# 4  N Hollywood                1513        27.0          M              W
#
#   Premise Description                          Address  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481568 entries, 0 to 481567
# Data columns (total 20 columns):
# DR Number                            481568 non-null int64
# Date Reported                        481568 non-null object
# Date Occurred                        481568 non-null object
# Time Occurred                        481568 non-null int64
# Area Name                            481568 non-null object
# Reporting District                   481568 non-null int64
# Victim Age                           404022 non-null float64
# Victim Sex                           474522 non-null object
# Victim Descent                       473786 non-null object
# Premise Description                  481543 non-null object
# Address                              481568 non-null object
# Cross Street                         460022 non-null object
# Location                             481568 non-null object
# Zip Codes                            481170 non-null float64
# ...

# %%
data.drop(['Location'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481568 entries, 0 to 481567
# Data columns (total 15 columns):
# DR Number              481568 non-null int64
# Date Reported          481568 non-null object
# Date Occurred          481568 non-null object
# Time Occurred          481568 non-null int64
# Area Name              481568 non-null object
# Reporting District     481568 non-null int64
# Victim Age             404022 non-null float64
# Victim Sex             474522 non-null object
# Victim Descent         473786 non-null object
# Premise Description    481543 non-null object
# Address                481568 non-null object
# Cross Street           460022 non-null object
# Zip Codes              481170 non-null float64
# Latitude               481568 non-null float64
# Longitude              481568 non-null float64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 55.1+ MB

# %%
data.drop(['Zip Codes','Census Tracts','Precinct Boundaries','Council Districts','Neighborhood Councils (Certified)'],axis=1,inplace=True)

# %%
sns.distplot(data['Victim Age'].dropna())

# %%
sns.countplot(data['Victim Sex'].dropna())

# %%
data['Victim Sex'] = data['Victim Sex'].fillna('X')

# %%
sns.countplot(data['Victim Descent'].dropna())

# %%
data['Victim Descent'] = data['Victim Descent'].fillna('Z')

# %%
new_data = data[:]
new_data.to_csv('new_data.csv')

# %%
new_data.head()
# Out:
#    DR Number            Date Reported            Date Occurred  Time Occurred  \
# 0  191713007  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1040
# 1  191913696  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            850
# 2  191611704  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            910
# 3  191913694  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000            700
# 4  191514323  2019-07-20T00:00:00.000  2019-07-20T00:00:00.000           1200
#
#      Area Name  Reporting District  Victim Age Victim Sex Victim Descent  \
# 0   Devonshire                1788        32.0          F              W
# 1      Mission                1924        50.0          M              O
# 2     Foothill                1693        75.0          M              O
# 3      Mission                1964        40.0          M              H
# 4  N Hollywood                1513        27.0          M              W
#
#   Premise Description                          Address  \
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481568 entries, 0 to 481567
# Data columns (total 15 columns):
# DR Number              481568 non-null int64
# Date Reported          481568 non-null object
# Date Occurred          481568 non-null object
# Time Occurred          481568 non-null int64
# Area Name              481568 non-null object
# Reporting District     481568 non-null int64
# Victim Age             404022 non-null float64
# Victim Sex             481568 non-null object
# Victim Descent         481568 non-null object
# Premise Description    481543 non-null object
# Address                481568 non-null object
# Cross Street           460022 non-null object
# Zip Codes              481170 non-null float64
# Latitude               481568 non-null float64
# Longitude              481568 non-null float64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 55.1+ MB
